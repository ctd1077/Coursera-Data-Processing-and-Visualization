# %%
# Processing Text and Strings in Python

# %%
import pandas as pd
import string
import json

# %%
path = '/home/cambam/Desktop/Python/Coursera/Basic Data Processing and Visualization/Data Processing and Visualization/Data/review.json'

# %%
f = open(path)

# %%
d = json.loads(f.readline())

# %%
d
# Out:
# {'review_id': 'Q1sbwvVQXV2734tPgoKj4Q',
#  'user_id': 'hG7b0MtEbXx5QzbzE6C_VA',
#  'business_id': 'ujmEBvifdJM6h6RLv4wQIg',
#  'stars': 1.0,
#  'useful': 6,
#  'funny': 1,
#  'cool': 0,
#  'text': 'Total bill for this horrible service? Over $8Gs. These crooks actually had the nerve to charge us $69 for 3 pills. I checked online the pills can be had for 19 cents EACH! Avoid Hospital ERs at all costs.',
#  'date': '2013-05-07 04:34:36'}

# %%
review = d['text']

# %%
reviewWords = review.split()

# %%
reviewWords
# Out:
# ['Total',
#  'bill',
#  'for',
#  'this',
#  'horrible',
#  'service?',
#  'Over',
#  '$8Gs.',
#  'These',
#  'crooks',
#  'actually',
#  'had',
#  'the',
#  'nerve',
#  'to',
#  'charge',
#  'us',
#  '$69',
#  'for',
#  '3',
#  'pills.',
#  'I',
#  'checked',
#  'online',
#  'the',
#  'pills',
#  'can',
#  'be',
#  'had',
#  'for',
#  '19',
#  'cents',
#  'EACH!',
#  'Avoid',
#  'Hospital',
#  'ERs',
#  'at',
#  'all',
#  'costs.']

# %%
' '.join(reviewWords)
# Out:
# 'Total bill for this horrible service? Over $8Gs. These crooks actually had the nerve to charge us $69 for 3 pills. I checked online the pills can be had for 19 cents EACH! Avoid Hospital ERs at all costs.'

# %%
review.lower()
# Out:
# 'total bill for this horrible service? over $8gs. these crooks actually had the nerve to charge us $69 for 3 pills. i checked online the pills can be had for 19 cents each! avoid hospital ers at all costs.'

# %%
review.upper()
# Out:
# 'TOTAL BILL FOR THIS HORRIBLE SERVICE? OVER $8GS. THESE CROOKS ACTUALLY HAD THE NERVE TO CHARGE US $69 FOR 3 PILLS. I CHECKED ONLINE THE PILLS CAN BE HAD FOR 19 CENTS EACH! AVOID HOSPITAL ERS AT ALL COSTS.'

# %%
len(review)
# Out:
# 204

# %%
len(reviewWords)
# Out:
# 39

# %%
review[:10]
# Out:
# 'Total bill'

# %%
reviewWords[:10]
# Out:
# ['Total',
#  'bill',
#  'for',
#  'this',
#  'horrible',
#  'service?',
#  'Over',
#  '$8Gs.',
#  'These',
#  'crooks']

# %%
reviewWords.index('crooks')
# Out:
# 9

# %%
review.find('crooks')
# Out:
# 55

# %%
review.count('the')
# Out:
# 2

# %%
# Count is case sensitive 
review.lower().count('the')
# Out:
# 3

# %%
# You might want to remove punctuation in a review
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Removes all punctuations
[x for x in review if not x in string.punctuation]
# Out:
# ['T',
#  'o',
#  't',
#  'a',
#  'l',
#  ' ',
#  'b',
#  'i',
#  'l',
#  'l',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'h',
#  'o',
#  'r',
#  'r',
#  'i',
#  'b',
#  'l',
#  'e',
#  ' ',
#  's',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  ' ',
#  'O',
#  'v',
#  'e',
#  'r',
#  ' ',
#  '8',
#  'G',
#  's',
#  ' ',
#  'T',
#  'h',
#  'e',
#  's',
#  'e',
#  ' ',
#  'c',
#  'r',
#  'o',
#  'o',
#  'k',
#  's',
#  ' ',
#  'a',
#  'c',
#  't',
#  'u',
#  'a',
#  'l',
#  'l',
#  'y',
#  ' ',
#  'h',
#  'a',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'n',
#  'e',
#  'r',
#  'v',
#  'e',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'r',
#  'g',
#  'e',
#  ' ',
#  'u',
#  's',
#  ' ',
#  '6',
#  '9',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  '3',
#  ' ',
#  'p',
#  'i',
#  'l',
#  'l',
#  's',
#  ' ',
#  'I',
#  ' ',
#  'c',
#  'h',
#  'e',
#  'c',
#  'k',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  'l',
#  'i',
#  'n',
#  'e',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'p',
#  'i',
#  'l',
#  'l',
#  's',
#  ' ',
#  'c',
#  'a',
#  'n',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'h',
#  'a',
#  'd',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  '1',
#  '9',
#  ' ',
#  'c',
#  'e',
#  'n',
#  't',
#  's',
#  ' ',
#  'E',
#  'A',
#  'C',
#  'H',
#  ' ',
#  'A',
#  'v',
#  'o',
#  'i',
#  'd',
#  ' ',
#  'H',
#  'o',
#  's',
#  'p',
#  'i',
#  't',
#  'a',
#  'l',
#  ' ',
#  'E',
#  'R',
#  's',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'a',
#  'l',
#  'l',
#  ' ',
#  'c',
#  'o',
#  's',
#  't',
#  's']

# %%
# Joins all the letters and spaces back together without punctuation
''.join([x for x in review if not x in string.punctuation])
# Out:
# 'Total bill for this horrible service Over 8Gs These crooks actually had the nerve to charge us 69 for 3 pills I checked online the pills can be had for 19 cents EACH Avoid Hospital ERs at all costs'
